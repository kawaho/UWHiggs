# %%
import os
from sys import argv, stdout, stderr
from ROOT import TCanvas, TLegend, gROOT, TFile, gPad, TPad, TF1, gStyle, TGraphErrors
from array import array                                                                                                                                                            
import numpy as np
import sys
gROOT.SetStyle("Plain")
gROOT.SetBatch(True)
# Out:
# Welcome to JupyROOT 6.12/07

# %%
gStyle.SetOptFit(1)
canvas = TCanvas('canvas','canvas',800,800)
grid = TPad("grid", "", 0, 0, 1, 1)
grid.Draw()
grid.cd()
fi = TFile('FakeRate2016Deep/frEBDM0.root')
h = fi.Get('fakerate')
h.Draw()
gPad.Update()
graph = h.GetPaintedGraph()
h.SetTitle("|#eta|^{#tau} < 1.5 & Decay Mode 0; p_{T}^{#tau} (GeV); Tight-To-Loose")
graph.GetYaxis().SetTitleOffset(1.2)
graph.SetMinimum(0)
graph.SetMaximum(1.0)
gPad.Update()
f = TF1("Linear law","[0]+x*[1]", 0, 200)
f.SetLineColor(4)
f.SetLineStyle(0)
fitResult1 = h.Fit(f, "S")
steps = 500
x = np.linspace(10.0, 200.0, num=steps)                                                                                                                                    
y = np.array([fitResult1.GetParams()[0] + fitResult1.GetParams()[1]*x[i] for i in range(steps)])                                                                             
ey = np.array([fitResult1.GetErrors()[0] + fitResult1.GetErrors()[1]*x[i] for i in range(steps)])                                                                            
zeros = np.zeros(graph.GetN())                                                                                                                                             
interval = TGraphErrors(steps, x, y, zeros, ey)                                                                                                                            
interval.SetFillColor(2)                                                                                                                                                   
interval.SetFillStyle(3002)                                                                                                                                                
interval.Draw("e3 same")
canvas.Draw()
canvas.SaveAs("EBDM0.png")
# Out:
# Info in <TBinomialEfficiencyFitter::result>:  chi2 6.075662 ndf 0
# Info in <TCanvas::Print>: png file EBDM0.png has been created

# %%
gStyle.SetOptFit(1)
canvas = TCanvas('canvas','canvas',800,800)
grid = TPad("grid", "", 0, 0, 1, 1)
grid.Draw()
grid.cd()
fi = TFile('FakeRate2016Deep/frEBDM1.root')
h = fi.Get('fakerate')
h.Draw()
gPad.Update()
graph = h.GetPaintedGraph()
h.SetTitle("|#eta|^{#tau} < 1.5 & Decay Mode 1; p_{T}^{#tau} (GeV); Tight-To-Loose")
graph.GetYaxis().SetTitleOffset(1.2)
graph.SetMinimum(0)
graph.SetMaximum(1.0)
gPad.Update()
f = TF1("Linear law","[0]+x*[1]", 0, 200)
f.SetLineColor(4)
f.SetLineStyle(0)
fitResult2 = h.Fit(f, "S")
steps = 500
x = np.linspace(10.0, 200.0, num=steps)                                                                                                                                    
y = np.array([fitResult2.GetParams()[0] + fitResult2.GetParams()[1]*x[i] for i in range(steps)])                                                                             
ey = np.array([fitResult2.GetErrors()[0] + fitResult2.GetErrors()[1]*x[i] for i in range(steps)])                                                                            
zeros = np.zeros(graph.GetN())                                                                                                                                             
interval = TGraphErrors(steps, x, y, zeros, ey)                                                                                                                            
interval.SetFillColor(2)                                                                                                                                                   
interval.SetFillStyle(3002)                                                                                                                                                
interval.Draw("e3 same")
canvas.Draw()
canvas.SaveAs("EBDM1.png")
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TBinomialEfficiencyFitter::result>:  chi2 6.426593 ndf 0
# Info in <TCanvas::Print>: png file EBDM1.png has been created

# %%
gStyle.SetOptFit(1)
canvas = TCanvas('canvas','canvas',800,800)
grid = TPad("grid", "", 0, 0, 1, 1)
grid.Draw()
grid.cd()
fi = TFile('FakeRate2016Deep/frEBDM10.root')
h = fi.Get('fakerate')
h.Draw()
gPad.Update()
graph = h.GetPaintedGraph()
h.SetTitle("|#eta|^{#tau} < 1.5 & Decay Mode 10; p_{T}^{#tau} (GeV); Tight-To-Loose")
graph.GetYaxis().SetTitleOffset(1.2)
graph.SetMinimum(0)
graph.SetMaximum(1.0)
gPad.Update()
f = TF1("Linear law","[0]+x*[1]", 0, 200)
f.SetLineColor(4)
f.SetLineStyle(0)
fitResult3 = h.Fit(f, "S")
steps = 500
x = np.linspace(10.0, 200.0, num=steps)                                                                                                                                    
y = np.array([fitResult3.GetParams()[0] + fitResult3.GetParams()[1]*x[i] for i in range(steps)])                                                                             
ey = np.array([fitResult3.GetErrors()[0] + fitResult3.GetErrors()[1]*x[i] for i in range(steps)])                                                                            
zeros = np.zeros(graph.GetN())                                                                                                                                             
interval = TGraphErrors(steps, x, y, zeros, ey)                                                                                                                            
interval.SetFillColor(2)                                                                                                                                                   
interval.SetFillStyle(3002)                                                                                                                                                
interval.Draw("e3 same")
canvas.Draw()
canvas.SaveAs("EBDM10.png")
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TBinomialEfficiencyFitter::result>:  chi2 5.702876 ndf 0
# Info in <TCanvas::Print>: png file EBDM10.png has been created

# %%
gStyle.SetOptFit(1)
canvas = TCanvas('canvas','canvas',800,800)
grid = TPad("grid", "", 0, 0, 1, 1)
grid.Draw()
grid.cd()
fi = TFile('FakeRate2016Deep/frEBDM11.root')
h = fi.Get('fakerate')
h.Draw()
gPad.Update()
graph = h.GetPaintedGraph()
h.SetTitle("|#eta|^{#tau} < 1.5 & Decay Mode 11; p_{T}^{#tau} (GeV); Tight-To-Loose")
graph.GetYaxis().SetTitleOffset(1.2)
graph.SetMinimum(0)
graph.SetMaximum(1.0)
gPad.Update()
f = TF1("Linear law","[0]+x*[1]", 0, 200)
f.SetLineColor(4)
f.SetLineStyle(0)
fitResult4 = h.Fit(f, "S")
steps = 500
x = np.linspace(10.0, 200.0, num=steps)                                                                                                                                    
y = np.array([fitResult4.GetParams()[0] + fitResult4.GetParams()[1]*x[i] for i in range(steps)])                                                                             
ey = np.array([fitResult4.GetErrors()[0] + fitResult4.GetErrors()[1]*x[i] for i in range(steps)])                                                                            
zeros = np.zeros(graph.GetN())                                                                                                                                             
interval = TGraphErrors(steps, x, y, zeros, ey)                                                                                                                            
interval.SetFillColor(2)                                                                                                                                                   
interval.SetFillStyle(3002)                                                                                                                                                
interval.Draw("e3 same")
canvas.Draw()
canvas.SaveAs("EBDM11.png")
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TBinomialEfficiencyFitter::result>:  chi2 11.923152 ndf 0
# Info in <TCanvas::Print>: png file EBDM11.png has been created

# %%
gStyle.SetOptFit(1)
canvas = TCanvas('canvas','canvas',800,800)
grid = TPad("grid", "", 0, 0, 1, 1)
grid.Draw()
grid.cd()
fi = TFile('FakeRate2016Deep/frEEDM0.root')
h = fi.Get('fakerate')
h.Draw()
gPad.Update()
graph = h.GetPaintedGraph()
h.SetTitle("|#eta|^{#tau} > 1.5 & Decay Mode 0; p_{T}^{#tau} (GeV); Tight-To-Loose")
graph.GetYaxis().SetTitleOffset(1.2)
graph.SetMinimum(0)
graph.SetMaximum(1.0)
gPad.Update()
f = TF1("Linear law","[0]+x*[1]", 0, 200)
f.SetLineColor(4)
f.SetLineStyle(0)
fitResult5 = h.Fit(f, "S")
steps = 500
x = np.linspace(10.0, 200.0, num=steps)                                                                                                                                    
y = np.array([fitResult5.GetParams()[0] + fitResult5.GetParams()[1]*x[i] for i in range(steps)])                                                                             
ey = np.array([fitResult5.GetErrors()[0] + fitResult5.GetErrors()[1]*x[i] for i in range(steps)])                                                                            
zeros = np.zeros(graph.GetN())                                                                                                                                             
interval = TGraphErrors(steps, x, y, zeros, ey)                                                                                                                            
interval.SetFillColor(2)                                                                                                                                                   
interval.SetFillStyle(3002)                                                                                                                                                
interval.Draw("e3 same")
canvas.Draw()
canvas.SaveAs("EEDM0.png")
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TBinomialEfficiencyFitter::result>:  chi2 0.895508 ndf 0
# Info in <TCanvas::Print>: png file EEDM0.png has been created

# %%
gStyle.SetOptFit(1)
canvas = TCanvas('canvas','canvas',800,800)
grid = TPad("grid", "", 0, 0, 1, 1)
grid.Draw()
grid.cd()
fi = TFile('FakeRate2016Deep/frEEDM1.root')
h = fi.Get('fakerate')
h.Draw()
gPad.Update()
graph = h.GetPaintedGraph()
h.SetTitle("|#eta|^{#tau} > 1.5 & Decay Mode 1; p_{T}^{#tau} (GeV); Tight-To-Loose")
graph.GetYaxis().SetTitleOffset(1.2)
graph.SetMinimum(0)
graph.SetMaximum(1.0)
gPad.Update()
f = TF1("Linear law","[0]+x*[1]", 0, 200)
f.SetLineColor(4)
f.SetLineStyle(0)
fitResult6 = h.Fit(f, "S")
steps = 500
x = np.linspace(10.0, 200.0, num=steps)                                                                                                                                    
y = np.array([fitResult6.GetParams()[0] + fitResult6.GetParams()[1]*x[i] for i in range(steps)])                                                                             
ey = np.array([fitResult6.GetErrors()[0] + fitResult6.GetErrors()[1]*x[i] for i in range(steps)])                                                                            
zeros = np.zeros(graph.GetN())                                                                                                                                             
interval = TGraphErrors(steps, x, y, zeros, ey)                                                                                                                            
interval.SetFillColor(2)                                                                                                                                                   
interval.SetFillStyle(3002)                                                                                                                                                
interval.Draw("e3 same")
canvas.Draw()
canvas.SaveAs("EEDM1.png")
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TBinomialEfficiencyFitter::result>:  chi2 1.321967 ndf 0
# Info in <TCanvas::Print>: png file EEDM1.png has been created

# %%
gStyle.SetOptFit(1)
canvas = TCanvas('canvas','canvas',800,800)
grid = TPad("grid", "", 0, 0, 1, 1)
grid.Draw()
grid.cd()
fi = TFile('FakeRate2016Deep/frEEDM10.root')
h = fi.Get('fakerate')
h.Draw()
gPad.Update()
graph = h.GetPaintedGraph()
h.SetTitle("|#eta|^{#tau} > 1.5 & Decay Mode 10; p_{T}^{#tau} (GeV); Tight-To-Loose")
graph.GetYaxis().SetTitleOffset(1.2)
graph.SetMinimum(0)
graph.SetMaximum(1.0)
gPad.Update()
f = TF1("Linear law","[0]+x*[1]", 0, 200)
f.SetLineColor(4)
f.SetLineStyle(0)
fitResult7 = h.Fit(f, "S")
steps = 500
x = np.linspace(10.0, 200.0, num=steps)                                                                                                                                    
y = np.array([fitResult7.GetParams()[0] + fitResult7.GetParams()[1]*x[i] for i in range(steps)])                                                                             
ey = np.array([fitResult7.GetErrors()[0] + fitResult7.GetErrors()[1]*x[i] for i in range(steps)])                                                                            
zeros = np.zeros(graph.GetN())                                                                                                                                             
interval = TGraphErrors(steps, x, y, zeros, ey)                                                                                                                            
interval.SetFillColor(2)                                                                                                                                                   
interval.SetFillStyle(3002)                                                                                                                                                
interval.Draw("e3 same")
canvas.Draw()
canvas.SaveAs("EEDM10.png")
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TBinomialEfficiencyFitter::result>:  chi2 2.367143 ndf 0
# Info in <TCanvas::Print>: png file EEDM10.png has been created

# %%
gStyle.SetOptFit(1)
canvas = TCanvas('canvas','canvas',800,800)
grid = TPad("grid", "", 0, 0, 1, 1)
grid.Draw()
grid.cd()
fi = TFile('FakeRate2016Deep/frEEDM11.root')
h = fi.Get('fakerate')
h.Draw()
gPad.Update()
graph = h.GetPaintedGraph()
h.SetTitle("|#eta|^{#tau} > 1.5 & Decay Mode 11; p_{T}^{#tau} (GeV); Tight-To-Loose")
graph.GetYaxis().SetTitleOffset(1.2)
graph.SetMinimum(0)
graph.SetMaximum(1.0)
gPad.Update()
f = TF1("Linear law","[0]+x*[1]", 0, 200)
f.SetLineColor(4)
f.SetLineStyle(0)
fitResult8 = h.Fit(f, "S")
steps = 500
x = np.linspace(10.0, 200.0, num=steps)                                                                                                                                    
y = np.array([fitResult8.GetParams()[0] + fitResult8.GetParams()[1]*x[i] for i in range(steps)])                                                                             
ey = np.array([fitResult8.GetErrors()[0] + fitResult8.GetErrors()[1]*x[i] for i in range(steps)])                                                                            
zeros = np.zeros(graph.GetN())                                                                                                                                             
interval = TGraphErrors(steps, x, y, zeros, ey)                                                                                                                            
interval.SetFillColor(2)                                                                                                                                                   
interval.SetFillStyle(3002)                                                                                                                                                
interval.Draw("e3 same")
canvas.Draw()
canvas.SaveAs("EEDM11.png")
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TBinomialEfficiencyFitter::result>:  chi2 3.582476 ndf 0
# Info in <TCanvas::Print>: png file EEDM11.png has been created

# %%
gStyle.SetOptFit(1)
canvas = TCanvas('canvas','canvas',800,800)
legend = TLegend(0.5,0.6,0.88,0.8)
grid = TPad("grid", "", 0, 0, 1, 1)
grid.Draw()
grid.cd()
fi = TFile('FakeRate2016Deep/frEta.root')
h = fi.Get('fakerate')
hdy = fi.Get('dyfakerate')
hdy.SetLineColor(2)
legend.AddEntry(h,"Data","l")
legend.AddEntry(hdy,"Z+Jets","l")
h.Draw()
hdy.Draw("SAME")
gPad.Update()
graph = h.GetPaintedGraph()
h.SetTitle("Tau Fake Rate; Tau Eta; Fake Rate")
graph.SetMinimum(0)
graph.SetMaximum(1.0)
gPad.Update()
legend.Draw()
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Warning in <TEfficiency::GetEfficiencyErrorLow>: frequentist confidence intervals for weights are only supported by the normal approximation
# Info in <TEfficiency::GetEfficiencyErrorLow>: setting statistic option to kFNormal

# %%
f = TFile("FRMMT.root", "Recreate")
fitResult1.Write("EBDM0")
fitResult2.Write("EBDM1")
fitResult3.Write("EBDM10")
fitResult4.Write("EBDM11")
fitResult5.Write("EEDM0")
fitResult6.Write("EEDM1")
fitResult7.Write("EEDM10")
fitResult8.Write("EEDM11")
f.Close()
