# %%
import os
from sys import argv, stdout, stderr
from ROOT import TFile, gROOT, TCanvas, TLegend, TPad, TH1F
import sys                                                                                                                                                                                                                                                  
gROOT.SetStyle("Plain")                                                                                                                                                                                                                                           
gROOT.SetBatch(True)
# Out:
# Welcome to JupyROOT 6.12/07

# %%
canvas = TCanvas("canvas","canvas",800,800)
pad1 = TPad("pad1","pad1",0,0.3,1,1);pad1.SetBottomMargin(0.025);pad1.Draw();pad1.cd()
legend = TLegend(0.6,0.6,0.78,0.9)
legend.SetTextFont(43)
legend.SetTextSize(20)

f = TFile('GluGlu_LFV_HToMuTau_M125_13TeV_powheg_pythia8_v2-PU2017_12Apr2018_94X_mc2017_realistic_v14-v1.root')
h = f.Get('TightOS/lhe0/m_t_CollinearMass')
h.GetYaxis().SetTitle("Events/Bin");h.GetXaxis().SetLabelOffset(999);h.GetXaxis().SetTitleOffset(2.4);h.GetYaxis().SetTitleOffset(0.9);h.GetXaxis().SetTitleSize(30);h.GetYaxis().SetTitleSize(30);h.GetXaxis().SetLabelSize(20);h.GetYaxis().SetLabelSize(20);h.GetXaxis().SetTitleFont(43);h.GetYaxis().SetTitleFont(43);h.GetXaxis().SetLabelFont(43);h.GetYaxis().SetLabelFont(43)
h1 = f.Get('TightOS/lhe1/m_t_CollinearMass')
h2 = f.Get('TightOS/lhe2/m_t_CollinearMass')
h3 = f.Get('TightOS/lhe3/m_t_CollinearMass')
h4 = f.Get('TightOS/lhe4/m_t_CollinearMass')
h6 = f.Get('TightOS/lhe6/m_t_CollinearMass')
h8 = f.Get('TightOS/lhe8/m_t_CollinearMass')
h.SetMaximum(1.5*h.GetMaximum())
h.GetXaxis().SetRange(15,45);h1.GetXaxis().SetRange(15,45)
h1.SetLineColor(632);h2.SetLineColor(600);h3.SetLineColor(416);h4.SetLineColor(900);h6.SetLineColor(800);h8.SetLineColor(832)
h.Draw("HIST");h1.Draw("HISTSAME");h2.Draw("HISTSAME");h3.Draw("HISTSAME");h4.Draw("HISTSAME");h6.Draw("HISTSAME");h8.Draw("HISTSAME")
legend.AddEntry(h,"Nominal","l");legend.AddEntry(h1,"1d2d","l");legend.AddEntry(h2,"1d0.5d","l");legend.AddEntry(h3,"2d1d","l");legend.AddEntry(h4,"2d2d","l");legend.AddEntry(h6,"0.5d1d","l");legend.AddEntry(h8,"0.5d0.5d","l");legend.Draw("SAME")

canvas.cd()
pad2 = TPad("pad2","pad2",0,0,1,0.3);pad2.SetTopMargin(0.025);pad2.SetBottomMargin(0.25);pad2.Draw();pad2.cd()
h1c = h1.Clone("h1c");h1c.SetMinimum(0.5);h1c.SetMaximum(1.5);h1c.Sumw2();h1c.SetStats(0);h1c.Divide(h);h1c.Draw("ep")
h1c.SetTitle("");h1c.GetXaxis().SetTitle("Collinear Mass");h1c.GetYaxis().SetTitle("Ratio");h1c.GetXaxis().SetTitleOffset(2.4);h1c.GetYaxis().SetTitleOffset(0.9);h1c.GetXaxis().SetTitleSize(30);h1c.GetYaxis().SetTitleSize(30);h1c.GetXaxis().SetLabelSize(20);h1c.GetYaxis().SetLabelSize(20);h1c.GetXaxis().SetTitleFont(43);h1c.GetYaxis().SetTitleFont(43);h1c.GetXaxis().SetLabelFont(43);h1c.GetYaxis().SetLabelFont(43);h1c.GetYaxis().SetNdivisions(3)
h2c = h2.Clone("h2c");h2c.Sumw2();h2c.Divide(h);h2c.Draw("epsame")
h3c = h3.Clone("h3c");h3c.Sumw2();h3c.Divide(h);h3c.Draw("epsame")
h4c = h4.Clone("h4c");h4c.Sumw2();h4c.Divide(h);h4c.Draw("epsame")
h6c = h6.Clone("h6c");h6c.Sumw2();h6c.Divide(h);h6c.Draw("epsame")
h8c = h8.Clone("h8c");h8c.Sumw2();h8c.Divide(h);h8c.Draw("epsame")
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created

# %% [markdown]
# Scale Variation

# %%
canvas = TCanvas("canvas","canvas",800,800)
pad1 = TPad("pad1","pad1",0,0.3,1,1);pad1.SetBottomMargin(0.025);pad1.Draw();pad1.cd()
legend = TLegend(0.6,0.6,0.78,0.9)
legend.SetTextFont(43)
legend.SetTextSize(20)

f = TFile('GluGluHToWWTo2L2Nu_M125_13TeV_powheg2_JHUGenV714_pythia8_v2-PU2017_12Apr2018_94X_mc2017_realistic_v14-v1.root')
h = f.Get('TightOS0Jet/lhe0/m_t_CollinearMass');hn = f.Get('TightOS/lhe0/m_t_CollinearMass')
h.SetTitle("GluGlu_LFV 0Jet Scale Variation");h.GetYaxis().SetTitle("Events/Bin");h.GetXaxis().SetLabelOffset(999);h.GetXaxis().SetTitleOffset(2.4);h.GetYaxis().SetTitleOffset(0.9);h.GetXaxis().SetTitleSize(30);h.GetYaxis().SetTitleSize(30);h.GetXaxis().SetLabelSize(20);h.GetYaxis().SetLabelSize(20);h.GetXaxis().SetTitleFont(43);h.GetYaxis().SetTitleFont(43);h.GetXaxis().SetLabelFont(43);h.GetYaxis().SetLabelFont(43)
h1 = f.Get('TightOS0Jet/lhe1/m_t_CollinearMass');h1n = f.Get('TightOS/lhe1/m_t_CollinearMass')
h2 = f.Get('TightOS0Jet/lhe2/m_t_CollinearMass');h2n = f.Get('TightOS/lhe2/m_t_CollinearMass')
h3 = f.Get('TightOS0Jet/lhe3/m_t_CollinearMass');h3n = f.Get('TightOS/lhe3/m_t_CollinearMass')
h4 = f.Get('TightOS0Jet/lhe4/m_t_CollinearMass');h4n = f.Get('TightOS/lhe4/m_t_CollinearMass')
h6 = f.Get('TightOS0Jet/lhe6/m_t_CollinearMass');h6n = f.Get('TightOS/lhe6/m_t_CollinearMass')
h8 = f.Get('TightOS0Jet/lhe8/m_t_CollinearMass');h8n = f.Get('TightOS/lhe8/m_t_CollinearMass')
h.SetMaximum(1.5*h.GetMaximum())
#h.GetXaxis().SetRange(15,45);h1.GetXaxis().SetRange(15,45)
h.Scale(1/(hn.Integral()));h1.Scale(1/(h1n.Integral()));h2.Scale(1/(h2n.Integral()));h3.Scale(1/(h3n.Integral()));h4.Scale(1/(h4n.Integral()));h6.Scale(1/(h6n.Integral()));h8.Scale(1/(h8n.Integral()))
#h.Scale(1/(h.Integral()));h1.Scale(1/(h1.Integral()));h2.Scale(1/(h2.Integral()));h3.Scale(1/(h3.Integral()));h4.Scale(1/(h4.Integral()));h6.Scale(1/(h6.Integral()));h8.Scale(1/(h8.Integral()))
h1.SetLineColor(632);h2.SetLineColor(600);h3.SetLineColor(416);h4.SetLineColor(900);h6.SetLineColor(800);h8.SetLineColor(832)
h.Draw("HIST");h1.Draw("HISTSAME");h2.Draw("HISTSAME");h3.Draw("HISTSAME");h4.Draw("HISTSAME");h6.Draw("HISTSAME");h8.Draw("HISTSAME")
legend.AddEntry(h,"Nominal","l");legend.AddEntry(h1,"1d2d","l");legend.AddEntry(h2,"1d0.5d","l");legend.AddEntry(h3,"2d1d","l");legend.AddEntry(h4,"2d2d","l");legend.AddEntry(h6,"0.5d1d","l");legend.AddEntry(h8,"0.5d0.5d","l");legend.Draw("SAME")

canvas.cd()
pad2 = TPad("pad2","pad2",0,0,1,0.3);pad2.SetTopMargin(0.025);pad2.SetBottomMargin(0.25);pad2.Draw();pad2.cd()
h1c = h1.Clone("h1c");h1c.SetMinimum(0.8);h1c.SetMaximum(1.2);h1c.Sumw2();h1c.SetStats(0);h1c.Divide(h);h1c.Draw("ep")
h1c.SetTitle("");h1c.GetXaxis().SetTitle("Collinear Mass");h1c.GetYaxis().SetTitle("Ratio");h1c.GetXaxis().SetTitleOffset(2.4);h1c.GetYaxis().SetTitleOffset(0.9);h1c.GetXaxis().SetTitleSize(30);h1c.GetYaxis().SetTitleSize(30);h1c.GetXaxis().SetLabelSize(20);h1c.GetYaxis().SetLabelSize(20);h1c.GetXaxis().SetTitleFont(43);h1c.GetYaxis().SetTitleFont(43);h1c.GetXaxis().SetLabelFont(43);h1c.GetYaxis().SetLabelFont(43);h1c.GetYaxis().SetNdivisions(3)
h2c = h2.Clone("h2c");h2c.Sumw2();h2c.Divide(h);h2c.Draw("epsame")
h3c = h3.Clone("h3c");h3c.Sumw2();h3c.Divide(h);h3c.Draw("epsame")
h4c = h4.Clone("h4c");h4c.Sumw2();h4c.Divide(h);h4c.Draw("epsame")
h6c = h6.Clone("h6c");h6c.Sumw2();h6c.Divide(h);h6c.Draw("epsame")
h8c = h8.Clone("h8c");h8c.Sumw2();h8c.Divide(h);h8c.Draw("epsame")
canvas.Draw()

print "Scale Uncertainty: ", 0.5*(h4.Integral()-h8.Integral())/h.Integral()
# Out:
# Scale Uncertainty:  0.0517605843449
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created

# %%
canvas = TCanvas("canvas","canvas",800,800)
pad1 = TPad("pad1","pad1",0,0.3,1,1);pad1.SetBottomMargin(0.025);pad1.Draw();pad1.cd()
legend = TLegend(0.6,0.6,0.78,0.9)
legend.SetTextFont(43)
legend.SetTextSize(20)

f = TFile('GluGluHToWWTo2L2Nu_M125_13TeV_powheg2_JHUGenV714_pythia8_v2-PU2017_12Apr2018_94X_mc2017_realistic_v14-v1.root')
h = f.Get('TightOS1Jet/lhe0/m_t_CollinearMass');hn = f.Get('TightOS/lhe0/m_t_CollinearMass')
h.SetTitle("GluGlu_LFV 1Jet Scale Variation");h.GetYaxis().SetTitle("Events/Bin");h.GetXaxis().SetLabelOffset(999);h.GetXaxis().SetTitleOffset(2.4);h.GetYaxis().SetTitleOffset(0.9);h.GetXaxis().SetTitleSize(30);h.GetYaxis().SetTitleSize(30);h.GetXaxis().SetLabelSize(20);h.GetYaxis().SetLabelSize(20);h.GetXaxis().SetTitleFont(43);h.GetYaxis().SetTitleFont(43);h.GetXaxis().SetLabelFont(43);h.GetYaxis().SetLabelFont(43)
h1 = f.Get('TightOS1Jet/lhe1/m_t_CollinearMass');h1n = f.Get('TightOS/lhe1/m_t_CollinearMass')
h2 = f.Get('TightOS1Jet/lhe2/m_t_CollinearMass');h2n = f.Get('TightOS/lhe2/m_t_CollinearMass')
h3 = f.Get('TightOS1Jet/lhe3/m_t_CollinearMass');h3n = f.Get('TightOS/lhe3/m_t_CollinearMass')
h4 = f.Get('TightOS1Jet/lhe4/m_t_CollinearMass');h4n = f.Get('TightOS/lhe4/m_t_CollinearMass')
h6 = f.Get('TightOS1Jet/lhe6/m_t_CollinearMass');h6n = f.Get('TightOS/lhe6/m_t_CollinearMass')
h8 = f.Get('TightOS1Jet/lhe8/m_t_CollinearMass');h8n = f.Get('TightOS/lhe8/m_t_CollinearMass')
h.SetMaximum(1.5*h.GetMaximum())
#h.GetXaxis().SetRange(15,45);h1.GetXaxis().SetRange(15,45)
h.Scale(1/(hn.Integral()));h1.Scale(1/(h1n.Integral()));h2.Scale(1/(h2n.Integral()));h3.Scale(1/(h3n.Integral()));h4.Scale(1/(h4n.Integral()));h6.Scale(1/(h6n.Integral()));h8.Scale(1/(h8n.Integral()))
#h.Scale(1/(h.Integral()));h1.Scale(1/(h1.Integral()));h2.Scale(1/(h2.Integral()));h3.Scale(1/(h3.Integral()));h4.Scale(1/(h4.Integral()));h6.Scale(1/(h6.Integral()));h8.Scale(1/(h8.Integral()))
h1.SetLineColor(632);h2.SetLineColor(600);h3.SetLineColor(416);h4.SetLineColor(900);h6.SetLineColor(800);h8.SetLineColor(832)
h.Draw("HIST");h1.Draw("HISTSAME");h2.Draw("HISTSAME");h3.Draw("HISTSAME");h4.Draw("HISTSAME");h6.Draw("HISTSAME");h8.Draw("HISTSAME")
legend.AddEntry(h,"Nominal","l");legend.AddEntry(h1,"1d2d","l");legend.AddEntry(h2,"1d0.5d","l");legend.AddEntry(h3,"2d1d","l");legend.AddEntry(h4,"2d2d","l");legend.AddEntry(h6,"0.5d1d","l");legend.AddEntry(h8,"0.5d0.5d","l");legend.Draw("SAME")

canvas.cd()
pad2 = TPad("pad2","pad2",0,0,1,0.3);pad2.SetTopMargin(0.025);pad2.SetBottomMargin(0.25);pad2.Draw();pad2.cd()
h1c = h1.Clone("h1c");h1c.SetMinimum(0.8);h1c.SetMaximum(1.2);h1c.Sumw2();h1c.SetStats(0);h1c.Divide(h);h1c.Draw("ep")
h1c.SetTitle("");h1c.GetXaxis().SetTitle("Collinear Mass");h1c.GetYaxis().SetTitle("Ratio");h1c.GetXaxis().SetTitleOffset(2.4);h1c.GetYaxis().SetTitleOffset(0.9);h1c.GetXaxis().SetTitleSize(30);h1c.GetYaxis().SetTitleSize(30);h1c.GetXaxis().SetLabelSize(20);h1c.GetYaxis().SetLabelSize(20);h1c.GetXaxis().SetTitleFont(43);h1c.GetYaxis().SetTitleFont(43);h1c.GetXaxis().SetLabelFont(43);h1c.GetYaxis().SetLabelFont(43);h1c.GetYaxis().SetNdivisions(3)
h2c = h2.Clone("h2c");h2c.Sumw2();h2c.Divide(h);h2c.Draw("epsame")
h3c = h3.Clone("h3c");h3c.Sumw2();h3c.Divide(h);h3c.Draw("epsame")
h4c = h4.Clone("h4c");h4c.Sumw2();h4c.Divide(h);h4c.Draw("epsame")
h6c = h6.Clone("h6c");h6c.Sumw2();h6c.Divide(h);h6c.Draw("epsame")
h8c = h8.Clone("h8c");h8c.Sumw2();h8c.Divide(h);h8c.Draw("epsame")
canvas.Draw()

print "Scale Uncertainty: ", 0.5*(h4.Integral()-h8.Integral())/h.Integral()
# Out:
# Scale Uncertainty:  -0.0127139965574
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created

# %%
canvas = TCanvas("canvas","canvas",800,800)
pad1 = TPad("pad1","pad1",0,0.3,1,1);pad1.SetBottomMargin(0.025);pad1.Draw();pad1.cd()
legend = TLegend(0.6,0.6,0.78,0.9)
legend.SetTextFont(43)
legend.SetTextSize(20)

f = TFile('GluGluHToWWTo2L2Nu_M125_13TeV_powheg2_JHUGenV714_pythia8_v2-PU2017_12Apr2018_94X_mc2017_realistic_v14-v1.root')
h = f.Get('TightOS2Jet/lhe0/m_t_CollinearMass');hn = f.Get('TightOS/lhe0/m_t_CollinearMass')
h.SetTitle("GluGlu_LFV 2Jet & M_{jj} < 550 GeV  Scale Variation");h.GetYaxis().SetTitle("Events/Bin");h.GetXaxis().SetLabelOffset(999);h.GetXaxis().SetTitleOffset(2.4);h.GetYaxis().SetTitleOffset(0.9);h.GetXaxis().SetTitleSize(30);h.GetYaxis().SetTitleSize(30);h.GetXaxis().SetLabelSize(20);h.GetYaxis().SetLabelSize(20);h.GetXaxis().SetTitleFont(43);h.GetYaxis().SetTitleFont(43);h.GetXaxis().SetLabelFont(43);h.GetYaxis().SetLabelFont(43)
h1 = f.Get('TightOS2Jet/lhe1/m_t_CollinearMass');h1n = f.Get('TightOS/lhe1/m_t_CollinearMass')
h2 = f.Get('TightOS2Jet/lhe2/m_t_CollinearMass');h2n = f.Get('TightOS/lhe2/m_t_CollinearMass')
h3 = f.Get('TightOS2Jet/lhe3/m_t_CollinearMass');h3n = f.Get('TightOS/lhe3/m_t_CollinearMass')
h4 = f.Get('TightOS2Jet/lhe4/m_t_CollinearMass');h4n = f.Get('TightOS/lhe4/m_t_CollinearMass')
h6 = f.Get('TightOS2Jet/lhe6/m_t_CollinearMass');h6n = f.Get('TightOS/lhe6/m_t_CollinearMass')
h8 = f.Get('TightOS2Jet/lhe8/m_t_CollinearMass');h8n = f.Get('TightOS/lhe8/m_t_CollinearMass')
h.SetMaximum(1.5*h.GetMaximum())
#h.GetXaxis().SetRange(15,45);h1.GetXaxis().SetRange(15,45)
h.Scale(1/(hn.Integral()));h1.Scale(1/(h1n.Integral()));h2.Scale(1/(h2n.Integral()));h3.Scale(1/(h3n.Integral()));h4.Scale(1/(h4n.Integral()));h6.Scale(1/(h6n.Integral()));h8.Scale(1/(h8n.Integral()))
#h.Scale(1/(h.Integral()));h1.Scale(1/(h1.Integral()));h2.Scale(1/(h2.Integral()));h3.Scale(1/(h3.Integral()));h4.Scale(1/(h4.Integral()));h6.Scale(1/(h6.Integral()));h8.Scale(1/(h8.Integral()))
h1.SetLineColor(632);h2.SetLineColor(600);h3.SetLineColor(416);h4.SetLineColor(900);h6.SetLineColor(800);h8.SetLineColor(832)
h.Draw("HIST");h1.Draw("HISTSAME");h2.Draw("HISTSAME");h3.Draw("HISTSAME");h4.Draw("HISTSAME");h6.Draw("HISTSAME");h8.Draw("HISTSAME")
legend.AddEntry(h,"Nominal","l");legend.AddEntry(h1,"1d2d","l");legend.AddEntry(h2,"1d0.5d","l");legend.AddEntry(h3,"2d1d","l");legend.AddEntry(h4,"2d2d","l");legend.AddEntry(h6,"0.5d1d","l");legend.AddEntry(h8,"0.5d0.5d","l");legend.Draw("SAME")

canvas.cd()
pad2 = TPad("pad2","pad2",0,0,1,0.3);pad2.SetTopMargin(0.025);pad2.SetBottomMargin(0.25);pad2.Draw();pad2.cd()
h1c = h1.Clone("h1c");h1c.SetMinimum(0.8);h1c.SetMaximum(1.2);h1c.Sumw2();h1c.SetStats(0);h1c.Divide(h);h1c.Draw("ep")
h1c.SetTitle("");h1c.GetXaxis().SetTitle("Collinear Mass");h1c.GetYaxis().SetTitle("Ratio");h1c.GetXaxis().SetTitleOffset(2.4);h1c.GetYaxis().SetTitleOffset(0.9);h1c.GetXaxis().SetTitleSize(30);h1c.GetYaxis().SetTitleSize(30);h1c.GetXaxis().SetLabelSize(20);h1c.GetYaxis().SetLabelSize(20);h1c.GetXaxis().SetTitleFont(43);h1c.GetYaxis().SetTitleFont(43);h1c.GetXaxis().SetLabelFont(43);h1c.GetYaxis().SetLabelFont(43);h1c.GetYaxis().SetNdivisions(3)
h2c = h2.Clone("h2c");h2c.Sumw2();h2c.Divide(h);h2c.Draw("epsame")
h3c = h3.Clone("h3c");h3c.Sumw2();h3c.Divide(h);h3c.Draw("epsame")
h4c = h4.Clone("h4c");h4c.Sumw2();h4c.Divide(h);h4c.Draw("epsame")
h6c = h6.Clone("h6c");h6c.Sumw2();h6c.Divide(h);h6c.Draw("epsame")
h8c = h8.Clone("h8c");h8c.Sumw2();h8c.Divide(h);h8c.Draw("epsame")
canvas.Draw()

print "Scale Uncertainty: ", 0.5*(h4.Integral()-h8.Integral())/h.Integral()
# Out:
# Scale Uncertainty:  -0.052893520507
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created

# %%
canvas = TCanvas("canvas","canvas",800,800)
pad1 = TPad("pad1","pad1",0,0.3,1,1);pad1.SetBottomMargin(0.025);pad1.Draw();pad1.cd()
legend = TLegend(0.6,0.6,0.78,0.9)
legend.SetTextFont(43)
legend.SetTextSize(20)

f = TFile('GluGluHToWWTo2L2Nu_M125_13TeV_powheg2_JHUGenV714_pythia8_v2-PU2017_12Apr2018_94X_mc2017_realistic_v14-v1.root')
h = f.Get('TightOS2JetVBF/lhe0/m_t_CollinearMass');hn = f.Get('TightOS/lhe0/m_t_CollinearMass')
h.SetTitle("GluGlu_LFV 2Jet & M_{jj} > 550 GeV  Scale Variation");h.GetYaxis().SetTitle("Events/Bin");h.GetXaxis().SetLabelOffset(999);h.GetXaxis().SetTitleOffset(2.4);h.GetYaxis().SetTitleOffset(0.9);h.GetXaxis().SetTitleSize(30);h.GetYaxis().SetTitleSize(30);h.GetXaxis().SetLabelSize(20);h.GetYaxis().SetLabelSize(20);h.GetXaxis().SetTitleFont(43);h.GetYaxis().SetTitleFont(43);h.GetXaxis().SetLabelFont(43);h.GetYaxis().SetLabelFont(43)
h1 = f.Get('TightOS2JetVBF/lhe1/m_t_CollinearMass');h1n = f.Get('TightOS/lhe1/m_t_CollinearMass')
h2 = f.Get('TightOS2JetVBF/lhe2/m_t_CollinearMass');h2n = f.Get('TightOS/lhe2/m_t_CollinearMass')
h3 = f.Get('TightOS2JetVBF/lhe3/m_t_CollinearMass');h3n = f.Get('TightOS/lhe3/m_t_CollinearMass')
h4 = f.Get('TightOS2JetVBF/lhe4/m_t_CollinearMass');h4n = f.Get('TightOS/lhe4/m_t_CollinearMass')
h6 = f.Get('TightOS2JetVBF/lhe6/m_t_CollinearMass');h6n = f.Get('TightOS/lhe6/m_t_CollinearMass')
h8 = f.Get('TightOS2JetVBF/lhe8/m_t_CollinearMass');h8n = f.Get('TightOS/lhe8/m_t_CollinearMass')
h.SetMaximum(1.5*h.GetMaximum())
#h.GetXaxis().SetRange(15,45);h1.GetXaxis().SetRange(15,45)
h.Scale(1/(hn.Integral()));h1.Scale(1/(h1n.Integral()));h2.Scale(1/(h2n.Integral()));h3.Scale(1/(h3n.Integral()));h4.Scale(1/(h4n.Integral()));h6.Scale(1/(h6n.Integral()));h8.Scale(1/(h8n.Integral()))
#h.Scale(1/(h.Integral()));h1.Scale(1/(h1.Integral()));h2.Scale(1/(h2.Integral()));h3.Scale(1/(h3.Integral()));h4.Scale(1/(h4.Integral()));h6.Scale(1/(h6.Integral()));h8.Scale(1/(h8.Integral()))
h1.SetLineColor(632);h2.SetLineColor(600);h3.SetLineColor(416);h4.SetLineColor(900);h6.SetLineColor(800);h8.SetLineColor(832)
h.Draw("HIST");h1.Draw("HISTSAME");h2.Draw("HISTSAME");h3.Draw("HISTSAME");h4.Draw("HISTSAME");h6.Draw("HISTSAME");h8.Draw("HISTSAME")
legend.AddEntry(h,"Nominal","l");legend.AddEntry(h1,"1d2d","l");legend.AddEntry(h2,"1d0.5d","l");legend.AddEntry(h3,"2d1d","l");legend.AddEntry(h4,"2d2d","l");legend.AddEntry(h6,"0.5d1d","l");legend.AddEntry(h8,"0.5d0.5d","l");legend.Draw("SAME")

canvas.cd()
pad2 = TPad("pad2","pad2",0,0,1,0.3);pad2.SetTopMargin(0.025);pad2.SetBottomMargin(0.25);pad2.Draw();pad2.cd()
h1c = h1.Clone("h1c");h1c.SetMinimum(0.8);h1c.SetMaximum(1.2);h1c.Sumw2();h1c.SetStats(0);h1c.Divide(h);h1c.Draw("ep")
h1c.SetTitle("");h1c.GetXaxis().SetTitle("Collinear Mass");h1c.GetYaxis().SetTitle("Ratio");h1c.GetXaxis().SetTitleOffset(2.4);h1c.GetYaxis().SetTitleOffset(0.9);h1c.GetXaxis().SetTitleSize(30);h1c.GetYaxis().SetTitleSize(30);h1c.GetXaxis().SetLabelSize(20);h1c.GetYaxis().SetLabelSize(20);h1c.GetXaxis().SetTitleFont(43);h1c.GetYaxis().SetTitleFont(43);h1c.GetXaxis().SetLabelFont(43);h1c.GetYaxis().SetLabelFont(43);h1c.GetYaxis().SetNdivisions(3)
h2c = h2.Clone("h2c");h2c.Sumw2();h2c.Divide(h);h2c.Draw("epsame")
h3c = h3.Clone("h3c");h3c.Sumw2();h3c.Divide(h);h3c.Draw("epsame")
h4c = h4.Clone("h4c");h4c.Sumw2();h4c.Divide(h);h4c.Draw("epsame")
h6c = h6.Clone("h6c");h6c.Sumw2();h6c.Divide(h);h6c.Draw("epsame")
h8c = h8.Clone("h8c");h8c.Sumw2();h8c.Divide(h);h8c.Draw("epsame")
canvas.Draw()

print "Scale Uncertainty: ", 0.5*(h4.Integral()-h8.Integral())/h.Integral()
# Out:
# Scale Uncertainty:  -0.0700595349589
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created

# %% [markdown]
# Alpha S

# %%
canvas = TCanvas("canvas","canvas",800,800)
pad1 = TPad("pad1","pad1",0,0.3,1,1);pad1.SetBottomMargin(0.025);pad1.Draw();pad1.cd()
legend = TLegend(0.6,0.6,0.78,0.9)
legend.SetTextFont(43)
legend.SetTextSize(20)

f = TFile('GluGluHToWWTo2L2Nu_M125_13TeV_powheg2_JHUGenV714_pythia8_v2-PU2017_12Apr2018_94X_mc2017_realistic_v14-v1.root')
h = f.Get('TightOS0Jet/lhe0/m_t_CollinearMass');hn = f.Get('TightOS/lhe0/m_t_CollinearMass')
h.SetTitle("GluGlu_LFV 0Jet #alpha_{s}");h.GetYaxis().SetTitle("Events/Bin");h.GetXaxis().SetLabelOffset(999);h.GetXaxis().SetTitleOffset(2.4);h.GetYaxis().SetTitleOffset(0.9);h.GetXaxis().SetTitleSize(30);h.GetYaxis().SetTitleSize(30);h.GetXaxis().SetLabelSize(20);h.GetYaxis().SetLabelSize(20);h.GetXaxis().SetTitleFont(43);h.GetYaxis().SetTitleFont(43);h.GetXaxis().SetLabelFont(43);h.GetYaxis().SetLabelFont(43)
h1 = f.Get('TightOS0Jet/lhe116/m_t_CollinearMass');h1n = f.Get('TightOS/lhe116/m_t_CollinearMass')
h2 = f.Get('TightOS0Jet/lhe117/m_t_CollinearMass');h2n = f.Get('TightOS/lhe117/m_t_CollinearMass')
h.SetMaximum(1.5*h.GetMaximum())
h.Scale(1/(hn.Integral()));h1.Scale(1/(h1n.Integral()));h2.Scale(1/(h2n.Integral()))
h1.SetLineColor(632);h2.SetLineColor(600)
h.Draw("HIST");h1.Draw("HISTSAME");h2.Draw("HISTSAME")
legend.AddEntry(h,"#alpha_{s} = 0.118","l");legend.AddEntry(h1,"#alpha_{s} = 0.117","l");legend.AddEntry(h2,"#alpha_{s} = 0.119","l");legend.Draw("SAME")

canvas.cd()
pad2 = TPad("pad2","pad2",0,0,1,0.3);pad2.SetTopMargin(0.025);pad2.SetBottomMargin(0.25);pad2.Draw();pad2.cd()
h1c = h1.Clone("h1c");h1c.SetMinimum(0.8);h1c.SetMaximum(1.2);h1c.Sumw2();h1c.SetStats(0);h1c.Divide(h);h1c.Draw("ep")
h1c.SetTitle("");h1c.GetXaxis().SetTitle("Collinear Mass");h1c.GetYaxis().SetTitle("Ratio");h1c.GetXaxis().SetTitleOffset(2.4);h1c.GetYaxis().SetTitleOffset(0.9);h1c.GetXaxis().SetTitleSize(30);h1c.GetYaxis().SetTitleSize(30);h1c.GetXaxis().SetLabelSize(20);h1c.GetYaxis().SetLabelSize(20);h1c.GetXaxis().SetTitleFont(43);h1c.GetYaxis().SetTitleFont(43);h1c.GetXaxis().SetLabelFont(43);h1c.GetYaxis().SetLabelFont(43);h1c.GetYaxis().SetNdivisions(3)
h2c = h2.Clone("h2c");h2c.Sumw2();h2c.Divide(h);h2c.Draw("epsame")
canvas.Draw()

print "Scale Uncertainty: ", 0.75*(h2.Integral()-h1.Integral())/h.Integral()
# Out:
# Scale Uncertainty:  -0.00320270131285
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created

# %%
canvas = TCanvas("canvas","canvas",800,800)
pad1 = TPad("pad1","pad1",0,0.3,1,1);pad1.SetBottomMargin(0.025);pad1.Draw();pad1.cd()
legend = TLegend(0.6,0.6,0.78,0.9)
legend.SetTextFont(43)
legend.SetTextSize(20)

f = TFile('GluGluHToWWTo2L2Nu_M125_13TeV_powheg2_JHUGenV714_pythia8_v2-PU2017_12Apr2018_94X_mc2017_realistic_v14-v1.root')
h = f.Get('TightOS1Jet/lhe0/m_t_CollinearMass');hn = f.Get('TightOS/lhe0/m_t_CollinearMass')
h.SetTitle("GluGlu_LFV 1Jet #alpha_{s}");h.GetYaxis().SetTitle("Events/Bin");h.GetXaxis().SetLabelOffset(999);h.GetXaxis().SetTitleOffset(2.4);h.GetYaxis().SetTitleOffset(0.9);h.GetXaxis().SetTitleSize(30);h.GetYaxis().SetTitleSize(30);h.GetXaxis().SetLabelSize(20);h.GetYaxis().SetLabelSize(20);h.GetXaxis().SetTitleFont(43);h.GetYaxis().SetTitleFont(43);h.GetXaxis().SetLabelFont(43);h.GetYaxis().SetLabelFont(43)
h1 = f.Get('TightOS1Jet/lhe116/m_t_CollinearMass');h1n = f.Get('TightOS/lhe116/m_t_CollinearMass')
h2 = f.Get('TightOS1Jet/lhe117/m_t_CollinearMass');h2n = f.Get('TightOS/lhe117/m_t_CollinearMass')
h.SetMaximum(1.5*h.GetMaximum())
h.Scale(1/(hn.Integral()));h1.Scale(1/(h1n.Integral()));h2.Scale(1/(h2n.Integral()))
h1.SetLineColor(632);h2.SetLineColor(600)
h.Draw("HIST");h1.Draw("HISTSAME");h2.Draw("HISTSAME")
legend.AddEntry(h,"#alpha_{s} = 0.118","l");legend.AddEntry(h1,"#alpha_{s} = 0.117","l");legend.AddEntry(h2,"#alpha_{s} = 0.119","l");legend.Draw("SAME")

canvas.cd()
pad2 = TPad("pad2","pad2",0,0,1,0.3);pad2.SetTopMargin(0.025);pad2.SetBottomMargin(0.25);pad2.Draw();pad2.cd()
h1c = h1.Clone("h1c");h1c.SetMinimum(0.8);h1c.SetMaximum(1.2);h1c.Sumw2();h1c.SetStats(0);h1c.Divide(h);h1c.Draw("ep")
h1c.SetTitle("");h1c.GetXaxis().SetTitle("Collinear Mass");h1c.GetYaxis().SetTitle("Ratio");h1c.GetXaxis().SetTitleOffset(2.4);h1c.GetYaxis().SetTitleOffset(0.9);h1c.GetXaxis().SetTitleSize(30);h1c.GetYaxis().SetTitleSize(30);h1c.GetXaxis().SetLabelSize(20);h1c.GetYaxis().SetLabelSize(20);h1c.GetXaxis().SetTitleFont(43);h1c.GetYaxis().SetTitleFont(43);h1c.GetXaxis().SetLabelFont(43);h1c.GetYaxis().SetLabelFont(43);h1c.GetYaxis().SetNdivisions(3)
h2c = h2.Clone("h2c");h2c.Sumw2();h2c.Divide(h);h2c.Draw("epsame")
canvas.Draw()

print "Scale Uncertainty: ", 0.75*(h2.Integral()-h1.Integral())/h.Integral()
# Out:
# Scale Uncertainty:  0.00113155120868
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created

# %%
canvas = TCanvas("canvas","canvas",800,800)
pad1 = TPad("pad1","pad1",0,0.3,1,1);pad1.SetBottomMargin(0.025);pad1.Draw();pad1.cd()
legend = TLegend(0.6,0.6,0.78,0.9)
legend.SetTextFont(43)
legend.SetTextSize(20)

f = TFile('GluGluHToWWTo2L2Nu_M125_13TeV_powheg2_JHUGenV714_pythia8_v2-PU2017_12Apr2018_94X_mc2017_realistic_v14-v1.root')
h = f.Get('TightOS2Jet/lhe0/m_t_CollinearMass');hn = f.Get('TightOS/lhe0/m_t_CollinearMass')
h.SetTitle("GluGlu_LFV 2Jet & M_{jj} < 550 GeV #alpha_{s}");h.GetYaxis().SetTitle("Events/Bin");h.GetXaxis().SetLabelOffset(999);h.GetXaxis().SetTitleOffset(2.4);h.GetYaxis().SetTitleOffset(0.9);h.GetXaxis().SetTitleSize(30);h.GetYaxis().SetTitleSize(30);h.GetXaxis().SetLabelSize(20);h.GetYaxis().SetLabelSize(20);h.GetXaxis().SetTitleFont(43);h.GetYaxis().SetTitleFont(43);h.GetXaxis().SetLabelFont(43);h.GetYaxis().SetLabelFont(43)
h1 = f.Get('TightOS2Jet/lhe116/m_t_CollinearMass');h1n = f.Get('TightOS/lhe116/m_t_CollinearMass')
h2 = f.Get('TightOS2Jet/lhe117/m_t_CollinearMass');h2n = f.Get('TightOS/lhe117/m_t_CollinearMass')
h.SetMaximum(1.5*h.GetMaximum())
h.Scale(1/(hn.Integral()));h1.Scale(1/(h1n.Integral()));h2.Scale(1/(h2n.Integral()))
h1.SetLineColor(632);h2.SetLineColor(600)
h.Draw("HIST");h1.Draw("HISTSAME");h2.Draw("HISTSAME")
legend.AddEntry(h,"#alpha_{s} = 0.118","l");legend.AddEntry(h1,"#alpha_{s} = 0.117","l");legend.AddEntry(h2,"#alpha_{s} = 0.119","l");legend.Draw("SAME")

canvas.cd()
pad2 = TPad("pad2","pad2",0,0,1,0.3);pad2.SetTopMargin(0.025);pad2.SetBottomMargin(0.25);pad2.Draw();pad2.cd()
h1c = h1.Clone("h1c");h1c.SetMinimum(0.8);h1c.SetMaximum(1.2);h1c.Sumw2();h1c.SetStats(0);h1c.Divide(h);h1c.Draw("ep")
h1c.SetTitle("");h1c.GetXaxis().SetTitle("Collinear Mass");h1c.GetYaxis().SetTitle("Ratio");h1c.GetXaxis().SetTitleOffset(2.4);h1c.GetYaxis().SetTitleOffset(0.9);h1c.GetXaxis().SetTitleSize(30);h1c.GetYaxis().SetTitleSize(30);h1c.GetXaxis().SetLabelSize(20);h1c.GetYaxis().SetLabelSize(20);h1c.GetXaxis().SetTitleFont(43);h1c.GetYaxis().SetTitleFont(43);h1c.GetXaxis().SetLabelFont(43);h1c.GetYaxis().SetLabelFont(43);h1c.GetYaxis().SetNdivisions(3)
h2c = h2.Clone("h2c");h2c.Sumw2();h2c.Divide(h);h2c.Draw("epsame")
canvas.Draw()

print "Scale Uncertainty: ", 0.75*(h2.Integral()-h1.Integral())/h.Integral()
# Out:
# Scale Uncertainty:  0.00232638822428
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created

# %%
canvas = TCanvas("canvas","canvas",800,800)
pad1 = TPad("pad1","pad1",0,0.3,1,1);pad1.SetBottomMargin(0.025);pad1.Draw();pad1.cd()
legend = TLegend(0.6,0.6,0.78,0.9)
legend.SetTextFont(43)
legend.SetTextSize(20)

f = TFile('GluGluHToWWTo2L2Nu_M125_13TeV_powheg2_JHUGenV714_pythia8_v2-PU2017_12Apr2018_94X_mc2017_realistic_v14-v1.root')
h = f.Get('TightOS2JetVBF/lhe0/m_t_CollinearMass');hn = f.Get('TightOS/lhe0/m_t_CollinearMass')
h.SetTitle("GluGlu_LFV 2Jet & M_{jj} > 550 GeV #alpha_{s}");h.GetYaxis().SetTitle("Events/Bin");h.GetXaxis().SetLabelOffset(999);h.GetXaxis().SetTitleOffset(2.4);h.GetYaxis().SetTitleOffset(0.9);h.GetXaxis().SetTitleSize(30);h.GetYaxis().SetTitleSize(30);h.GetXaxis().SetLabelSize(20);h.GetYaxis().SetLabelSize(20);h.GetXaxis().SetTitleFont(43);h.GetYaxis().SetTitleFont(43);h.GetXaxis().SetLabelFont(43);h.GetYaxis().SetLabelFont(43)
h1 = f.Get('TightOS2JetVBF/lhe116/m_t_CollinearMass');h1n = f.Get('TightOS/lhe116/m_t_CollinearMass')
h2 = f.Get('TightOS2JetVBF/lhe117/m_t_CollinearMass');h2n = f.Get('TightOS/lhe117/m_t_CollinearMass')
h.SetMaximum(1.5*h.GetMaximum())
h.Scale(1/(hn.Integral()));h1.Scale(1/(h1n.Integral()));h2.Scale(1/(h2n.Integral()))
h1.SetLineColor(632);h2.SetLineColor(600)
h.Draw("HIST");h1.Draw("HISTSAME");h2.Draw("HISTSAME")
legend.AddEntry(h,"#alpha_{s} = 0.118","l");legend.AddEntry(h1,"#alpha_{s} = 0.117","l");legend.AddEntry(h2,"#alpha_{s} = 0.119","l");legend.Draw("SAME")

canvas.cd()
pad2 = TPad("pad2","pad2",0,0,1,0.3);pad2.SetTopMargin(0.025);pad2.SetBottomMargin(0.25);pad2.Draw();pad2.cd()
h1c = h1.Clone("h1c");h1c.SetMinimum(0.8);h1c.SetMaximum(1.2);h1c.Sumw2();h1c.SetStats(0);h1c.Divide(h);h1c.Draw("ep")
h1c.SetTitle("");h1c.GetXaxis().SetTitle("Collinear Mass");h1c.GetYaxis().SetTitle("Ratio");h1c.GetXaxis().SetTitleOffset(2.4);h1c.GetYaxis().SetTitleOffset(0.9);h1c.GetXaxis().SetTitleSize(30);h1c.GetYaxis().SetTitleSize(30);h1c.GetXaxis().SetLabelSize(20);h1c.GetYaxis().SetLabelSize(20);h1c.GetXaxis().SetTitleFont(43);h1c.GetYaxis().SetTitleFont(43);h1c.GetXaxis().SetLabelFont(43);h1c.GetYaxis().SetLabelFont(43);h1c.GetYaxis().SetNdivisions(3)
h2c = h2.Clone("h2c");h2c.Sumw2();h2c.Divide(h);h2c.Draw("epsame")
canvas.Draw()

print "Scale Uncertainty: ", 0.75*(h2.Integral()-h1.Integral())/h.Integral()
# Out:
# Scale Uncertainty:  0.00536631099236
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created
# Warning in <TH1F::Sumw2>: Sum of squares of weights structure already created

# %% [markdown]
# PDF Uncertainty

# %%
canvas = TCanvas("canvas","canvas",800,800)
f = TFile('GluGluHToWWTo2L2Nu_M125_13TeV_powheg2_JHUGenV714_pythia8_v2-PU2017_12Apr2018_94X_mc2017_realistic_v14-v1.root')
pdfi = []
hp = TH1F("hp", "GluGlu_LFV 0Jet PDF Variation", 200, 0.95, 1.05)
for i in range(9, 112):
    h = f.Get('TightOS0Jet/lhe'+str(i)+'/m_t_CollinearMass')
    hn = f.Get('TightOS/lhe'+str(i)+'/m_t_CollinearMass')
    h.Scale(1/(hn.Integral()))
    pdfi.append(h.Integral())    
for j in range(len(pdfi)):
    hp.Fill(pdfi[j]/pdfi[0])
hp.GetXaxis().SetTitle("A_{pdf-variation}/A_{Nominal}")
hp.Draw()
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas

# %%
canvas = TCanvas("canvas","canvas",800,800)
f = TFile('GluGluHToWWTo2L2Nu_M125_13TeV_powheg2_JHUGenV714_pythia8_v2-PU2017_12Apr2018_94X_mc2017_realistic_v14-v1.root')
pdfi = []
hp = TH1F("hp", "GluGlu_LFV 1Jet PDF Variation", 200, 0.95, 1.05)
for i in range(9, 112):
    h = f.Get('TightOS1Jet/lhe'+str(i)+'/m_t_CollinearMass')
    hn = f.Get('TightOS/lhe'+str(i)+'/m_t_CollinearMass')
    h.Scale(1/(hn.Integral()))
    pdfi.append(h.Integral())    
for j in range(len(pdfi)):
    hp.Fill(pdfi[j]/pdfi[0])
hp.GetXaxis().SetTitle("A_{pdf-variation}/A_{Nominal}")
hp.Draw()
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas

# %%
canvas = TCanvas("canvas","canvas",800,800)
f = TFile('GluGluHToWWTo2L2Nu_M125_13TeV_powheg2_JHUGenV714_pythia8_v2-PU2017_12Apr2018_94X_mc2017_realistic_v14-v1.root')
pdfi = []
hp = TH1F("hp", "GluGlu_LFV 2Jet & M_{jj} < 550GeV PDF Variation", 200, 0.95, 1.05)
for i in range(9, 112):
    h = f.Get('TightOS2Jet/lhe'+str(i)+'/m_t_CollinearMass')
    hn = f.Get('TightOS/lhe'+str(i)+'/m_t_CollinearMass')
    h.Scale(1/(hn.Integral()))
    pdfi.append(h.Integral())    
for j in range(len(pdfi)):
    hp.Fill(pdfi[j]/pdfi[0])
hp.GetXaxis().SetTitle("A_{pdf-variation}/A_{Nominal}")
hp.Draw()
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas

# %%
canvas = TCanvas("canvas","canvas",800,800)
f = TFile('GluGluHToWWTo2L2Nu_M125_13TeV_powheg2_JHUGenV714_pythia8_v2-PU2017_12Apr2018_94X_mc2017_realistic_v14-v1.root')
pdfi = []
hp = TH1F("hp", "GluGlu_LFV 2Jet & M_{jj} > 550GeV PDF Variation", 200, 0.95, 1.05)
for i in range(9, 112):
    h = f.Get('TightOS2JetVBF/lhe'+str(i)+'/m_t_CollinearMass')
    hn = f.Get('TightOS/lhe'+str(i)+'/m_t_CollinearMass')
    h.Scale(1/(hn.Integral()))
    pdfi.append(h.Integral())    
for j in range(len(pdfi)):
    hp.Fill(pdfi[j]/pdfi[0])
hp.GetXaxis().SetTitle("A_{pdf-variation}/A_{Nominal}")
hp.Draw()
canvas.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
